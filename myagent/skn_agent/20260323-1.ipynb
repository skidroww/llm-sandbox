# %%
from geopy.geocoders import Nominatim

# %%
geo = Nominatim(user_agent='weather_app')

# %%
geo.geocode('분당')
# Out:
# Location(분당, 분당구, 성남시, 13588, 대한민국, (37.3777369, 127.1238612, 0.0))

# %%
url = "https://api.open-meteo.com/v1/forecast?latitude=37.3947237&longitude=127.1115312&current_weather=true"

# %%
import httpx

# %%
r = httpx.get(url)

# %%
r.json()
# Out:
# {'latitude': 37.4,
#  'longitude': 127.125,
#  'generationtime_ms': 0.10716915130615234,
#  'utc_offset_seconds': 0,
#  'timezone': 'GMT',
#  'timezone_abbreviation': 'GMT',
#  'elevation': 41.0,
#  'current_weather_units': {'time': 'iso8601',
#   'interval': 'seconds',
#   'temperature': '°C',
#   'windspeed': 'km/h',
#   'winddirection': '°',
#   'is_day': '',
#   'weathercode': 'wmo code'},
#  'current_weather': {'time': '2026-03-23T06:45',
#   'interval': 900,
#   'temperature': 16.4,
#   'windspeed': 4.4,
#   'winddirection': 325,
#   'is_day': 1,
#   'weathercode': 0}}

# %%
import pandas as pd

# %%
url = "https://wts-info-api.tossinvest.com/api/v2/stock-infos/A090430/overview"

# %%
rt = httpx.get(url).json()

# %%
rt['result']['company']
# Out:
# {'code': '090430',
#  'name': '아모레퍼시픽',
#  'englishName': 'AmorePacific',
#  'fullName': '아모레퍼시픽',
#  'fullEnglishName': 'AMOREPACIFIC CORPORATION',
#  'wics': {'code': 'G252065', 'displayName': '화장품'},
#  'industry': {'code': 'G252065', 'displayName': '화장품'},
#  'tics': None,
#  'description': '동사는 2006년 (주)아모레퍼시픽그룹을 인적분할하여 설립되었으며, 유가증권시장에 상장됨.',
#  'establishDate': '2006-06-01',
#  'establishYear': None,
#  'listDate': '2006-06-29',
#  'delistDate': None,
#  'ceo': '서경배, 김승환, 이동순',
#  'homepageUrl': 'http://www.apgroup.com',
#  'logoImageUrl': 'https://static.toss.im/png-icons/securities/icn-sec-fill-090430.png',
#  'createdAt': '2019-10-10T22:29:35',
#  'updatedAt': '2025-12-09T05:13:12',
#  'sharesOutstanding': 69050589,
#  'marketValue': 8451233234000,
#  'marketValueKrw': 8451233234000,
#  'currency': 'KRW',
#  'comment': {'code': '090430',
#   'comments': ['아모레퍼시픽은 2006년 6월 1일에 아모레퍼시픽그룹(구 태평양)을 인적분할하여 설립되었으며, 2006년 6월 29일 유가증권시장에 주식을 상장함.',
# ...

# %%
df = pd.read_csv(r"C:\Users\playdata2\Desktop\20260312_openapikey\myagent\data_2058_20260323.csv", encoding='cp949')
df[df['한글 종목명'].apply(lambda x : x.find("아모레퍼시픽") > -1)].to_json()
# Out:
# '{"\\ud45c\\uc900\\ucf54\\ub4dc":{"1251":"KR7090431008","1252":"KR7090430000","1253":"KR7002791002","1254":"KR700279K010","1255":"KR7002790004"},"\\ub2e8\\ucd95\\ucf54\\ub4dc":{"1251":"090435","1252":"090430","1253":"002795","1254":"00279K","1255":"002790"},"\\ud55c\\uae00 \\uc885\\ubaa9\\uba85":{"1251":"\\uc544\\ubaa8\\ub808\\ud37c\\uc2dc\\ud53d 1\\uc6b0\\uc120\\uc8fc","1252":"\\uc544\\ubaa8\\ub808\\ud37c\\uc2dc\\ud53d \\ubcf4\\ud1b5\\uc8fc","1253":"\\uc544\\ubaa8\\ub808\\ud37c\\uc2dc\\ud53d\\ud640\\ub529\\uc2a41\\uc6b0\\uc120\\uc8fc","1254":"\\uc544\\ubaa8\\ub808\\ud37c\\uc2dc\\ud53d\\ud640\\ub529\\uc2a43\\uc6b0\\uc120\\uc8fc(\\uc804\\ud658)","1255":"\\uc544\\ubaa8\\ub808\\ud37c\\uc2dc\\ud53d\\ud640\\ub529\\uc2a4\\ubcf4\\ud1b5\\uc8fc"},"\\ud55c\\uae00 \\uc885\\ubaa9\\uc57d\\uba85":{"1251":"\\uc544\\ubaa8\\ub808\\ud37c\\uc2dc\\ud53d\\uc6b0","1252":"\\uc544\\ubaa8\\ub808\\ud37c\\uc2dc\\ud53d","1253":"\\uc544\\ubaa8\\ub808\\ud37c\\uc2dc\\ud53d\\ud640\\ub529\\uc2a4\\uc6b0","1254":"\\uc
# ...
